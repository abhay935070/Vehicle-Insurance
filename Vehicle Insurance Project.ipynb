# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Vehicle_Insurance.csv')

# %%
df
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# # --> Checking Nullvalues

# %%
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %% [markdown]
# # --> Checking Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # --> Getting information with info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %% [markdown]
# # --> Get Describe

# %%
df.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %% [markdown]
# # --> Check coorelation with numeric only

# %%
df.corr(numeric_only=True)
# Out:
#                             id       Age  Driving_License  Region_Code  \
# id                    1.000000  0.001561        -0.000564    -0.000572
# Age                   0.001561  1.000000        -0.079782     0.042574
# Driving_License      -0.000564 -0.079782         1.000000    -0.001081
# Region_Code          -0.000572  0.042574        -0.001081     1.000000
# Previously_Insured    0.002457 -0.254682         0.014969    -0.024659
# Annual_Premium        0.003027  0.067507        -0.011906    -0.010588
# Policy_Sales_Channel -0.002837 -0.577826         0.043731    -0.042420
# Vintage              -0.000630 -0.001264        -0.000848    -0.002750
# Response             -0.001368  0.111147         0.010155     0.010570
#
#                       Previously_Insured  Annual_Premium  \
# id                              0.002457        0.003027
# Age                            -0.254682        0.067507
# Driving_License                 0.014969       -0.011906
# ...

# %% [markdown]
# # --> Showing null values in heatmap

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # --> Check the outlier use of Boxplot

# %%
sns.boxplot(df.Annual_Premium,orient='h')
plt.show()

# %%
Q1,Q3 = df.Annual_Premium.quantile([0.25,0.75])
Q1,Q3
# Out:
# (24405.0, 39400.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# 14995.0

# %%
UL = Q3 + 1.75 * (IQR)
LL = Q1 - 1.75 * (IQR)
UL,LL
# Out:
# (65641.25, -1836.25)

# %%
df[df.Annual_Premium>UL]
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 37          38  Female   25                1         28.0                   1
# 67          68    Male   60                1         28.0                   0
# 149        150  Female   22                1         11.0                   1
# 167        168  Female   26                1          8.0                   0
# 176        177    Male   25                1         28.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 380815  380816  Female   32                1         28.0                   1
# 380860  380861  Female   64                1         28.0                   0
# 380998  380999  Female   33                1          8.0                   0
# 381047  381048  Female   52                1          8.0                   1
# 381079  381080    Male   33                1         28.0                   0
#
# ...

# %%
df['Annual_Premium'] = np.where(df.Annual_Premium>UL,UL,df.Annual_Premium)

# %%
sns.boxplot(df.Annual_Premium,orient='h')
# Out:
# <Axes: xlabel='Annual_Premium'>

# %%
sns.boxplot(df.Vintage,orient='h')
plt.show()

# %% [markdown]
# # --> Changing the column type for better visualization

# %%
df['Gender'] = df['Gender'].replace({'M': 'Male', 'F': 'Female'})
df['Vehicle_Damage'] = df['Vehicle_Damage'].map({'Yes': 1, 'No': 0})
df['Vehicle_Age'] = df['Vehicle_Age'].map({'< 1 Year': 0, '1-2 Year': 1, '> 2 Years': 2})

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0            2               1         40454.0                  26.0      217
# 1            1               0         33536.0                  26.0      183
# 2            2               1         38294.0                  26.0       27
# 3            0               0         28619.0                 152.0      203
# 4            0               0         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# # --> Vehicel Insurance this dataset is show all insurance information.
#     # This dataset has no nunvalues
#     # No duplicates values
#     # But one column is annual_premium has many outliers and check the IQR method. So we solve the outlier in this data.
#     # After completeing the EDA.

# %% [markdown]
# # --> Visualization

# %% [markdown]
# # --> we create Visualization to show better for this dataset.
#     # Use heatmap to show the nullvalues.
#     # Use heatmap to show the correlation in numeric values.
#     # Create other plots Bar, Pie ,Hist to show the data.

# %%
sns.histplot(df['Age'], bins=30, kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(df['Annual_Premium'], bins=30, kde=True)
plt.title("Annual Premium Distribution")
plt.show()

# %%
sns.countplot(x='Vehicle_Damage',hue='Response',data=df)
plt.title('vehical Damage vs Response')
plt.show()

# %%
df['Gender'].value_counts().plot(kind='pie',color=['blue','pink'])
plt.title('Gender Distribution')
plt.show()

# %%
sns.countplot(x='Driving_License',data=df)
plt.title('Driving_License ownership')
plt.show()

# %%
sns.countplot(x='Previously_Insured',data=df,palette='magma')
plt.title('Previously_Insured vs Not insured')
plt.show()

# %%
sns.countplot(x='Vehicle_Damage', hue='Response', data=df)
plt.title("Vehicle Damage vs Response")
plt.show()

# %%
sns.countplot(x='Vehicle_Age', data=df,palette='coolwarm')
plt.title("Vehicle Age Distribution")
plt.show()

# %%
sns.histplot(df['Annual_Premium'], bins=30, kde=True)
plt.title("Annual Premium Distribution")
plt.show()

# %%
df['Policy_Sales_Channel'].value_counts().head(10).plot(kind='bar', color='blue')
plt.title("Top 10 Policy Sales Channels")
plt.show()

# %%
sns.histplot(df['Vintage'], bins=30, kde=True)
plt.title("Customer Vintage Distribution")
plt.show()

# %%
df['Region_Code'].value_counts().head(10).plot(kind='bar', color='purple')
plt.title("Top 10 Regions for Policy Sales")
plt.show()

# %%
sns.scatterplot(x='Age', y='Annual_Premium', data=df)
plt.title("Age vs Annual Premium")
plt.show()

# %% [markdown]
# # Key insights
#     # Mostly vehicle age in histplot are shown not skewed this plot.
#     # Mostly Damage vehicles are not responses for damages.
#     # Pie plot are shown the highely males are used to the vehicle compare by women.
#     # Highely persons are vehicle drived with driving license.
#     # Mostly vehicles are aged use in the city.
#     # Bar plot are shown in top 10 region by policy sales to see which policy are high.
#     # Annual premium are highly purchase the age of 20 to 80.
